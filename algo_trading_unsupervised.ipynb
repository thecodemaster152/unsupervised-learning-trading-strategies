# %% [markdown]
# <a href="https://colab.research.google.com/github/thecodemaster152/unsupervised-learning-trading-strategies/blob/main/algo_trading_unsupervised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("this is just to print")
# Out:
# this is just to print
